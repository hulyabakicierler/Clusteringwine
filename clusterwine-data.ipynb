# %% [markdown]
# # Wine Dataset for Clustering

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/wine-dataset-for-clustering/wine-clustering.csv

# %% [markdown]
# Bu veri seti , gözetimsiz öğrenme için şarap türleri hakkındaki bilgilerin çıkarılmasıyla https://archive.ics.uci.edu/ml/datasets/wine adresindeki Şarap Veri Setinden uyarlanmıştır .
#
# Aşağıdaki açıklamalar UCI web sayfasından uyarlanmıştır:
#
# Bu veriler, İtalya'nın aynı bölgesinde yetiştirilen ancak üç farklı kültürden elde edilen şarapların kimyasal analizinin sonuçlarıdır. Analiz, üç şarap türünün her birinde bulunan 13 bileşenin miktarını belirlemişt
# ir.
#
# Nitelikler şunla
#
# r+ dır:
# +
# Alkol
# Ma+ lik + asit
# Kül
# Kül al+ kalinitesi+
# Magnezyum
# Top+ lam fenoller
# +
# Flavonoidler
# Flavonoid ol+ mayan fenoller
# Pr+ oantosiyaninler+
# Renk yoğ+ unluğu
# Renk tonu
# Seyreltilmiş şarapl+ arın OD280/OD315'i
# Prolin

# %%
import pandas as pd
pd.set_option('display.max_columns',100)

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from yellowbrick.cluster import KElbowVisualizer

from scipy.cluster.hierarchy import dendrogram, linkage

# %%
df=pd.read_csv('/kaggle/input/wine-dataset-for-clustering/wine-clustering.csv')

# %% [markdown]
# # EDA

# %%
df.head()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0    14.23        1.71  2.43          15.6        127           2.80
# 1    13.20        1.78  2.14          11.2        100           2.65
# 2    13.16        2.36  2.67          18.6        101           2.80
# 3    14.37        1.95  2.50          16.8        113           3.85
# 4    13.24        2.59  2.87          21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    OD280  Proline
# 0   3.92     1065
# 1   3.40     1050
# 2   3.17     1185
# ...

# %%
df.shape
# Out:
# (178, 13)

# %%
df.columns
# Out:
# Index(['Alcohol', 'Malic_Acid', 'Ash', 'Ash_Alcanity', 'Magnesium',
#        'Total_Phenols', 'Flavanoids', 'Nonflavanoid_Phenols',
#        'Proanthocyanins', 'Color_Intensity', 'Hue', 'OD280', 'Proline'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Alcohol               178 non-null    float64
#  1   Malic_Acid            178 non-null    float64
#  2   Ash                   178 non-null    float64
#  3   Ash_Alcanity          178 non-null    float64
#  4   Magnesium             178 non-null    int64
#  5   Total_Phenols         178 non-null    float64
#  6   Flavanoids            178 non-null    float64
#  7   Nonflavanoid_Phenols  178 non-null    float64
#  8   Proanthocyanins       178 non-null    float64
#  9   Color_Intensity       178 non-null    float64
#  10  Hue                   178 non-null    float64
#  11  OD280                 178 non-null    float64
#  12  Proline               178 non-null    int64
# dtypes: float64(11), int64(2)
# memory usage: 18.2 KB

# %%
df.isnull().sum()
# Out:
# Alcohol                 0
# Malic_Acid              0
# Ash                     0
# Ash_Alcanity            0
# Magnesium               0
# Total_Phenols           0
# Flavanoids              0
# Nonflavanoid_Phenols    0
# Proanthocyanins         0
# Color_Intensity         0
# Hue                     0
# OD280                   0
# Proline                 0
# dtype: int64

# %%
df.tail()
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 173    13.71        5.65  2.45          20.5         95           1.68
# 174    13.40        3.91  2.48          23.0        102           1.80
# 175    13.27        4.28  2.26          20.0        120           1.59
# 176    13.17        2.59  2.37          20.0        120           1.65
# 177    14.13        4.10  2.74          24.5         96           2.05
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 173        0.61                  0.52             1.06              7.7  0.64
# 174        0.75                  0.43             1.41              7.3  0.70
# 175        0.69                  0.43             1.35             10.2  0.59
# 176        0.68                  0.53             1.46              9.3  0.60
# 177        0.76                  0.56             1.35              9.2  0.61
#
#      OD280  Proline
# 173   1.74      740
# 174   1.56      750
# ...

# %%
df.sample()
# Out:
#    Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 7    14.06        2.15  2.61          17.6        121            2.6
#
#    Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 7        2.51                  0.31             1.25             5.05  1.06
#
#    OD280  Proline
# 7   3.58     1295

# %% [markdown]
# # Veri Görselleştirme ve Feature Engineering

# %%
plt.figure(figsize=(21,13))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='viridis');

# %%
abs(df.corr(numeric_only=True)['Hue']).sort_values(ascending=False)
# Out:
# Hue                     1.000000
# Cluster                 0.668993
# OD280                   0.565468
# Malic_Acid              0.561296
# Flavanoids              0.543479
# Color_Intensity         0.521813
# Total_Phenols           0.433681
# Proanthocyanins         0.295544
# Ash_Alcanity            0.273955
# Nonflavanoid_Phenols    0.262640
# Proline                 0.236183
# Ash                     0.074667
# Alcohol                 0.071747
# Magnesium               0.055398
# Name: Hue, dtype: float64

# %%
df
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      14.23        1.71  2.43          15.6        127           2.80
# 1      13.20        1.78  2.14          11.2        100           2.65
# 2      13.16        2.36  2.67          18.6        101           2.80
# 3      14.37        1.95  2.50          16.8        113           3.85
# 4      13.24        2.59  2.87          21.0        118           2.80
# ..       ...         ...   ...           ...        ...            ...
# 173    13.71        5.65  2.45          20.5         95           1.68
# 174    13.40        3.91  2.48          23.0        102           1.80
# 175    13.27        4.28  2.26          20.0        120           1.59
# 176    13.17        2.59  2.37          20.0        120           1.65
# 177    14.13        4.10  2.74          24.5         96           2.05
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# ...

# %% [markdown]
# # Modelleme

# %%
model = KMeans(7)

# %%
model = model.fit(df)

# %%
pred = model.predict(df)

# %%
df["cluster"] = pred

# %%
df
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0      14.23        1.71  2.43          15.6        127           2.80
# 1      13.20        1.78  2.14          11.2        100           2.65
# 2      13.16        2.36  2.67          18.6        101           2.80
# 3      14.37        1.95  2.50          16.8        113           3.85
# 4      13.24        2.59  2.87          21.0        118           2.80
# ..       ...         ...   ...           ...        ...            ...
# 173    13.71        5.65  2.45          20.5         95           1.68
# 174    13.40        3.91  2.48          23.0        102           1.80
# 175    13.27        4.28  2.26          20.0        120           1.59
# 176    13.17        2.59  2.37          20.0        120           1.65
# 177    14.13        4.10  2.74          24.5         96           2.05
#
#      Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# ...

# %%
silhouette_score(df,pred)
# Out:
# 0.5624058579610122

# %%
km= KMeans()
vis=KElbowVisualizer(km,k=(2,10))
vis.fit(df)
vis.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %%
data  = linkage(df,method="ward",metric="euclidean")
plt.figure(figsize=(25,10))
dendrogram(data);

# %%
import pickle

# KMeans veya başka bir kümeleme modelini eğittikten sonra
model = kmeans  # modelinizin adı kmeans ise

# Modeli bir dosyaya kaydetme
with open('kmeans_model.pkl', 'wb') as file:
    pickle.dump(model, file)

# %%
df[df['cluster']==1]
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 59     12.37        0.94  1.36          10.6         88           1.98
# 61     12.64        1.36  2.02          16.8        100           2.02
# 66     13.11        1.01  1.70          15.0         78           2.98
# 67     12.37        1.17  1.92          19.6         78           2.11
# 72     13.49        1.66  2.24          24.0         87           1.88
# 77     11.84        2.89  2.23          18.0        112           1.72
# 79     12.70        3.87  2.40          23.0        101           2.83
# 83     13.05        3.86  2.32          22.5         85           1.65
# 84     11.84        0.89  2.58          18.0         94           2.20
# 85     12.67        0.98  2.24          18.0         99           2.20
# 86     12.16        1.61  2.31          22.8         90           1.78
# 87     11.65        1.67  2.62          26.0         88           1.92
# ...

# %%
df[df['cluster']==2]
# Out:
#     Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 2     13.16        2.36  2.67          18.6        101           2.80
# 6     14.39        1.87  2.45          14.6         96           2.50
# 7     14.06        2.15  2.61          17.6        121           2.60
# 11    14.12        1.48  2.32          16.8         95           2.20
# 12    13.75        1.73  2.41          16.0         89           2.60
# 15    13.63        1.81  2.70          17.2        112           2.85
# 16    14.30        1.92  2.72          20.0        120           2.80
# 26    13.39        1.77  2.62          16.1         93           2.85
# 27    13.30        1.72  2.14          17.0         94           2.40
# 30    13.73        1.50  2.70          22.5        101           3.00
# 33    13.76        1.53  2.70          19.5        132           2.95
# 49    13.94        1.73  2.27          17.4        108           2.88
# ...

# %%
df[df['cluster']==3]
# Out:
#     Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 0     14.23        1.71  2.43          15.6        127           2.80
# 1     13.20        1.78  2.14          11.2        100           2.65
# 8     14.83        1.64  2.17          14.0         97           2.80
# 9     13.86        1.35  2.27          16.0         98           2.98
# 13    14.75        1.73  2.39          11.4         91           3.10
# 17    13.83        1.57  2.62          20.0        115           2.95
# 22    13.71        1.86  2.36          16.6        101           2.61
# 23    12.85        1.60  2.52          17.8         95           2.48
# 29    14.02        1.68  2.21          16.0         96           2.65
# 32    13.68        1.83  2.36          17.2        104           2.42
# 34    13.51        1.80  2.65          19.0        110           2.35
# 37    13.05        1.65  2.55          18.0         98           2.45
# ...

# %%
df[df['cluster']==4]
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 63     12.37        1.13  2.16          19.0         87           3.50
# 64     12.17        1.45  2.53          19.0        104           1.89
# 71     13.86        1.51  2.67          25.0         86           2.95
# 75     11.66        1.88  1.92          16.0         97           1.61
# 76     13.03        0.90  1.71          16.0         86           1.95
# 80     12.00        0.92  2.00          19.0         86           2.42
# 93     12.29        2.83  2.22          18.0         88           2.45
# 94     11.62        1.99  2.28          18.0         98           3.02
# 97     12.29        1.41  1.98          16.0         85           2.55
# 99     12.29        3.17  2.21          18.0         88           2.85
# 102    12.34        2.45  2.46          21.0         98           2.56
# 103    11.82        1.72  1.88          19.5         86           2.50
# ...

# %%
df[df['cluster']==5]
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 4      13.24        2.59  2.87          21.0        118           2.80
# 39     14.22        3.99  2.51          13.2        128           3.00
# 43     13.24        3.98  2.29          17.5        103           2.64
# 60     12.33        1.10  2.28          16.0        101           2.05
# 62     13.67        1.25  1.92          18.0         94           2.10
# 65     12.37        1.21  2.56          18.1         98           2.42
# 68     13.34        0.94  2.36          17.0        110           2.53
# 69     12.21        1.19  1.75          16.8        151           1.85
# 78     12.33        0.99  1.95          14.8        136           1.90
# 81     12.72        1.81  2.20          18.8         86           2.20
# 82     12.08        1.13  2.51          24.0         78           2.00
# 88     11.64        2.06  2.46          21.6         84           1.95
# ...

# %%
df[df['cluster']==6]
# Out:
#     Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 3     14.37        1.95  2.50          16.8        113           3.85
# 5     14.20        1.76  2.45          15.2        112           3.27
# 10    14.10        2.16  2.30          18.0        105           2.95
# 14    14.38        1.87  2.38          12.0        102           3.30
# 18    14.19        1.59  2.48          16.5        108           3.30
# 31    13.58        1.66  2.36          19.1        106           2.86
#
#     Flavanoids  Nonflavanoid_Phenols  Proanthocyanins  Color_Intensity   Hue  \
# 3         3.49                  0.24             2.18             7.80  0.86
# 5         3.39                  0.34             1.97             6.75  1.05
# 10        3.32                  0.22             2.38             5.75  1.25
# 14        3.64                  0.29             2.96             7.50  1.20
# 18        3.93                  0.32             1.86             8.70  1.23
# ...

# %%
df[df['cluster']==0]
# Out:
#      Alcohol  Malic_Acid   Ash  Ash_Alcanity  Magnesium  Total_Phenols  \
# 19     13.64        3.10  2.56          15.2        116           2.70
# 20     14.06        1.63  2.28          16.0        126           3.00
# 21     12.93        3.80  2.65          18.6        102           2.41
# 24     13.50        1.81  2.61          20.0         96           2.53
# 25     13.05        2.05  3.22          25.0        124           2.63
# 28     13.87        1.90  2.80          19.4        107           2.95
# 35     13.48        1.81  2.41          20.5        100           2.70
# 36     13.28        1.64  2.84          15.5        110           2.60
# 40     13.56        1.71  2.31          16.2        117           3.15
# 44     13.05        1.77  2.10          17.0        107           3.00
# 70     12.29        1.61  2.21          20.4        103           1.10
# 74     11.96        1.09  2.30          21.0        101           3.38
# ...
